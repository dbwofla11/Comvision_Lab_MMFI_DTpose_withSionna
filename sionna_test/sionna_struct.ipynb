# %%
import pickle

with open(
    "perturbation_dataset_v1.pkl",
    "rb"
) as f:
    data = pickle.load(f)

print(type(data))
print(len(data))
print(data[0].keys())
print(data[0])
# Out:
# <class 'list'>
# 1000
# dict_keys(['env_id', 'num_objects', 'objects', 'mean_amp', 'factor', 'CSIamp', 'CSIphase', 'tau'])
# {'env_id': 0, 'num_objects': 1, 'objects': [{'type': 'table', 'pos': (-0.21545384061230832, 1.9706977091316187, 1.2628128830427752)}], 'mean_amp': 0.0002460717223584652, 'factor': 1.4043689966201782, 'CSIamp': array([[[[[[[2.24455929e-04],
#             [4.74259665e-04],
#             [2.24455842e-04],
#             [1.20243625e-04],
#             [1.20243640e-04],
#             [8.37178304e-05],
#             [3.26965441e-04],
#             [3.27005429e-04],
#             [4.00179706e-04],
#             [4.00179822e-04],
#             [4.74259665e-04],
#             [4.77572205e-04],
#             [6.02473214e-04],
#             [1.94115666e-04],
#             [1.38816235e-04],
#             [4.74259665e-04],
#             [4.74259665e-04],
#             [2.28071935e-04],
#             [1.72127984e-05],
#             [9.91898560e-05],
# ...

# %%
import numpy as np

factors = np.array([
    x["factor"]
    for x in data
])

factor_mean = factors.mean()

sample = random.choice(
    perturb_data
)

factor = (
    sample["factor"]
    / factor_mean
)

csi[0] *= factor
